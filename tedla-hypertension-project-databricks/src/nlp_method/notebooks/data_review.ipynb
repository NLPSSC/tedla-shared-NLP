# %%
import pandas as pd
import pyarrow.dataset as pds
from dotenv import load_dotenv

load_dotenv("/home/westerd/_/research_projects/tedla-hypertension/src/nlp_method/.env")


def load_sample(pth: str) -> pd.DataFrame:
    ds = pds.dataset(pth, format="parquet")
    scanner = ds.scanner(batch_size=100)
    batches = scanner.to_batches()
    df: pd.DataFrame | None = None
    try:
        first_batch = next(batches)
        df = first_batch.to_pandas()
    except StopIteration:
        df = pd.DataFrame()

    assert df is not None
    return df

#

# %%
import os
cohort_note_data_batched_path = os.getenv('COHORT_NOTE_DATA_TABLE')
display(pds.dataset(cohort_note_data_batched_path, format="parquet").to_table().num_rows)
# Out:
# 120970437

# %%
import os
import pyarrow.dataset as ds

COHORT_NOTE_DATA_TABLE = os.getenv('COHORT_NOTE_DATA_TABLE')
dataset = ds.dataset(COHORT_NOTE_DATA_TABLE, format="parquet")

total_rows = sum(fragment.count_rows() for fragment in dataset.get_fragments())
print(total_rows)

# %%
import os
import pyarrow.dataset as ds

COHORT_NOTE_DATA_TABLE = os.getenv('COHORT_NOTE_DATA_TABLE')
dataset = ds.dataset(COHORT_NOTE_DATA_TABLE, format="parquet")

note_ids = set()
for batch in dataset.to_batches(columns=["note_id"]):
    note_ids.update(batch.column("note_id").to_pylist())

print(f"Distinct note_id count: {len(note_ids)}")
# Out:
# Distinct note_id count: 120970437

# %%
import os
cohort_note_data_batched_path = os.getenv('COHORT_NOTE_DATA_TABLE')
note_data_ds = pds.dataset(cohort_note_data_batched_path, format="parquet")
from time import time

batch_size = 10000
note_data_table = note_data_ds.to_table()
num_rows = note_data_table.num_rows

for start in range(0, num_rows, batch_size):
    end = min(start + batch_size, num_rows)
    start_time = time()
    batch_table = note_data_table.slice(start, end - start)
    display(time() - start_time)
# Out:
# 0.009372472763061523
# 2.6226043701171875e-05
# 8.344650268554688e-06
# 8.821487426757812e-06
# 6.198883056640625e-06
# 4.76837158203125e-06
# 1.621246337890625e-05
# 7.867813110351562e-06
# 6.198883056640625e-06
# 5.0067901611328125e-06
# 5.4836273193359375e-06
# 6.198883056640625e-06
# 1.4066696166992188e-05
# 5.7220458984375e-06
# 5.7220458984375e-06
# 4.76837158203125e-06
# 5.245208740234375e-06
# 5.7220458984375e-06
# 1.5497207641601562e-05
# 5.7220458984375e-06
# 6.198883056640625e-06
# 4.291534423828125e-06
# 4.0531158447265625e-06
# 5.7220458984375e-06
# 5.4836273193359375e-06
# 1.3589859008789062e-05
# 5.4836273193359375e-06
# 5.4836273193359375e-06
# 4.5299530029296875e-06
# 5.7220458984375e-06
# 5.4836273193359375e-06
# 1.52587890625e-05
# 5.245208740234375e-06
# 6.4373016357421875e-06
# 4.76837158203125e-06
# 5.9604644775390625e-06
# 5.4836273193359375e-06
# 2.6464462280273438e-05
# 5.9604644775390625e-06
# 4.76837158203125e-06
# 1.239776611328125e-05
# ...

# %%
import os
cohort_note_data_batched_path = os.getenv('COHORT_NOTE_DATA_TABLE')
assert cohort_note_data_batched_path is not None

display(load_sample(cohort_note_data_batched_path).loc[0])
# Out:
# row_id                                                          2
# note_id                                       3323673853577564606
# person_id                                                 5567087
# note_text               married  2 children  employed  non-smoker
# note_date                                              2018-01-29
# note_type_concept_id                                            0
# note_title                                         social history
# note_source_value                                  social history
# x_source                                                  epic_sh
# note_concept_name                             no matching concept
# visit_occurrence_id                                           NaN
# batch_group                                                     1
# Name: 0, dtype: object

# %%
import os
note_id_to_note_groups_path = os.getenv('NOTE_ID_TO_NOTE_GROUPS_TABLE')
assert note_id_to_note_groups_path is not None
display(load_sample(note_id_to_note_groups_path).loc[0])
# Out:
# note_id                          5994593542118813621
# notes_problem_lists                                0
# notes_outpatient                                   0
# notes_inpatient                                    1
# notes_emergency_department                         0
# notes_ecg_impression                               0
# notes_discharge_summary                            0
# notes_communication_encounter                      0
# notes_admissions                                   0
# Name: 0, dtype: int64

# %%
import os
cohort_note_visit_details = os.getenv('COHORT_NOTE_VISIT_DETAILS')
assert cohort_note_visit_details is not None
display(load_sample(cohort_note_visit_details).loc[0])
# Out:
# note_id                5667425279318225505
# visit_occurrence_id              323503346
# visit_start_date                2021-11-15
# visit_end_date                  2021-11-15
# Name: 0, dtype: object
